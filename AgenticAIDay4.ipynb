# %%
import os
import google.generativeai as genai
try:
    os.environ["GOOGLE_API_KEY"] = "AIzaSyDZNN2CMACNhB5cd5IWcAFjwoHu0al1CnA"  # Replace with your actual API key or set it in your environment
    genai.configure(api_key=os.environ["GOOGLE_API_KEY"])
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
import logging
import os

# Clean up any previous logs
for log_file in ["logger.log", "web.log", "tunnel.log"]:
    if os.path.exists(log_file):
        os.remove(log_file)
        print(f"🧹 Cleaned up {log_file}")

# Configure logging with DEBUG log level.
logging.basicConfig(
    filename="logger.log",
    level=logging.DEBUG,
    format="%(filename)s:%(lineno)s %(levelname)s:%(message)s",
)

print("✅ Logging configured")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[15], line 7
#       5 for log_file in ["logger.log", "web.log", "tunnel.log"]:
#       6     if os.path.exists(log_file):
# ----> 7         os.remove(log_file)
#       8         print(f"🧹 Cleaned up {log_file}")
#      10 # Configure logging with DEBUG log level.
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'logger.log'

# %%
# Install missing package required for the jupyter_server import
# %pip install jupyter-server

from IPython.display import display, HTML
from jupyter_server.serverapp import list_running_servers


# Gets the proxied URL in the Kaggle Notebooks environment
def get_adk_proxy_url():
    PROXY_HOST = "https://kkb-production.jupyter-proxy.kaggle.net"
    ADK_PORT = "8000"

    servers = list(list_running_servers())
    if not servers:
        raise Exception("No running Jupyter servers found.")

    baseURL = servers[0]["base_url"]

    try:
        path_parts = baseURL.split("/")
        kernel = path_parts[2]
        token = path_parts[3]
    except IndexError:
        raise Exception(f"Could not parse kernel/token from base URL: {baseURL}")

    url_prefix = f"/k/{kernel}/{token}/proxy/proxy/{ADK_PORT}"
    url = f"{PROXY_HOST}{url_prefix}"

    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>⚠️ IMPORTANT: Action Required</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
            <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
                <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
                <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
            </ol>
            <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI (after running cell below) ↗
        </a>
    </div>
    """

    display(HTML(styled_html))

    return url_prefix


print("✅ Helper functions defined.")
# Out:
# Collecting jupyter-server
#   Downloading jupyter_server-2.17.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from jupyter-server) (4.12.0)
# Collecting argon2-cffi>=21.1 (from jupyter-server)
#   Downloading argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting jinja2>=3.0.3 (from jupyter-server)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\ashis\appdata\roaming\python\python314\site-packages (from jupyter-server) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ashis\appdata\roaming\python\python314\site-packages (from jupyter-server) (5.9.1)
# Collecting jupyter-events>=0.11.0 (from jupyter-server)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server)
#   Downloading nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server)
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=22.0 in c:\users\ashis\appdata\roaming\python\python314\site-packages (from jupyter-server) (25.0)
# Collecting prometheus-client>=0.9 (from jupyter-server)
#   Downloading prometheus_client-0.23.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pywinpty>=2.0.1 (from jupyter-server)
#   Downloading pywinpty-3.0.2-cp314-cp314-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: pyzmq>=24 in c:\users\ashis\appdata\roaming\python\python314\site-packages (from jupyter-server) (27.1.0)
# Collecting send2trash>=1.8.2 (from jupyter-server)
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server)
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\ashis\appdata\roaming\python\python314\site-packages (from jupyter-server) (6.5.2)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\ashis\appdata\roaming\python\python314\site-packages (from jupyter-server) (5.14.3)
# Collecting websocket-client>=1.7 (from jupyter-server)
#   Downloading websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from anyio>=3.1.0->jupyter-server) (3.11)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server)
#   Downloading argon2_cffi_bindings-25.1.0-cp39-abi3-win_amd64.whl.metadata (7.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from jinja2>=3.0.3->jupyter-server) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ashis\appdata\roaming\python\python314\site-packages (from jupyter-client>=7.4.4->jupyter-server) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ashis\appdata\roaming\python\python314\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server) (4.5.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server) (4.25.1)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server)
#   Downloading python_json_logger-4.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server) (6.0.3)
# Requirement already satisfied: referencing in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server) (0.37.0)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server) (0.29.0)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting rfc3987-syntax>=1.1.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server)
#   Downloading rfc3987_syntax-1.1.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server)
#   Downloading webcolors-25.10.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting beautifulsoup4 (from nbconvert>=6.4.4->jupyter-server)
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server)
#   Downloading bleach-6.3.0-py3-none-any.whl.metadata (31 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server)
#   Downloading mistune-3.1.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server)
#   Downloading nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\ashis\appdata\roaming\python\python314\site-packages (from nbconvert>=6.4.4->jupyter-server) (2.19.2)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server)
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server)
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ashis\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server) (1.17.0)
# Collecting lark>=1.2.2 (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server)
#   Downloading lark-1.3.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: cffi>=2.0.0b1 in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from cffi>=2.0.0b1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server) (2.23)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server) (4.15.0)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server)
#   Downloading arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: tzdata in c:\users\ashis\appdata\local\programs\python\python314\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server) (2025.2)
# Downloading jupyter_server-2.17.0-py3-none-any.whl (388 kB)
# Downloading argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Downloading mistune-3.1.4-py3-none-any.whl (53 kB)
# Downloading bleach-6.3.0-py3-none-any.whl (164 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading prometheus_client-0.23.1-py3-none-any.whl (61 kB)
# Downloading python_json_logger-4.0.0-py3-none-any.whl (15 kB)
# Downloading pywinpty-3.0.2-cp314-cp314-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 10.8 MB/s  0:00:00
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3987_syntax-1.1.0-py3-none-any.whl (8.0 kB)
# Downloading lark-1.3.1-py3-none-any.whl (113 kB)
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading webcolors-25.10.0-py3-none-any.whl (14 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Downloading argon2_cffi_bindings-25.1.0-cp39-abi3-win_amd64.whl (31 kB)
# Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, fastjsonschema, websocket-client, webcolors, uri-template, tinycss2, soupsieve, send2trash, rfc3986-validator, rfc3339-validator, pywinpty, python-json-logger, prometheus-client, pandocfilters, mistune, lark, jupyterlab-pygments, jsonpointer, jinja2, fqdn, defusedxml, bleach, terminado, rfc3987-syntax, beautifulsoup4, arrow, argon2-cffi-bindings, jupyter-server-terminals, isoduration, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server
#
#    - --------------------------------------  1/35 [fastjsonschema]
#    -- -------------------------------------  2/35 [websocket-client]
#    -- -------------------------------------  2/35 [websocket-client]
#    -- -------------------------------------  2/35 [websocket-client]
#    -- -------------------------------------  2/35 [websocket-client]
#    -- -------------------------------------  2/35 [websocket-client]
#    ---- -----------------------------------  4/35 [uri-template]
#    ----- ----------------------------------  5/35 [tinycss2]
#    ------ ---------------------------------  6/35 [soupsieve]
#    -------- -------------------------------  7/35 [send2trash]
#    -------- -------------------------------  7/35 [send2trash]
#    ---------- -----------------------------  9/35 [rfc3339-validator]
#    ------------ --------------------------- 11/35 [python-json-logger]
#    ------------- -------------------------- 12/35 [prometheus-client]
#    ------------- -------------------------- 12/35 [prometheus-client]
#    ------------- -------------------------- 12/35 [prometheus-client]
#    ---------------- ----------------------- 14/35 [mistune]
#    ---------------- ----------------------- 14/35 [mistune]
#    ---------------- ----------------------- 14/35 [mistune]
#    ----------------- ---------------------- 15/35 [lark]
#    ----------------- ---------------------- 15/35 [lark]
#    ----------------- ---------------------- 15/35 [lark]
#    ----------------- ---------------------- 15/35 [lark]
#    ------------------ --------------------- 16/35 [jupyterlab-pygments]
#    -------------------- ------------------- 18/35 [jinja2]
#    -------------------- ------------------- 18/35 [jinja2]
#    -------------------- ------------------- 18/35 [jinja2]
#    ---------------------- ----------------- 20/35 [defusedxml]
#    ------------------------ --------------- 21/35 [bleach]
#    ------------------------ --------------- 21/35 [bleach]
#    ------------------------ --------------- 21/35 [bleach]
#    ------------------------ --------------- 21/35 [bleach]
#    ------------------------ --------------- 21/35 [bleach]
#    -------------------------- ------------- 23/35 [rfc3987-syntax]
#    --------------------------- ------------ 24/35 [beautifulsoup4]
#    --------------------------- ------------ 24/35 [beautifulsoup4]
#    ---------------------------- ----------- 25/35 [arrow]
#    ------------------------------ --------- 27/35 [jupyter-server-terminals]
#    -------------------------------- ------- 28/35 [isoduration]
#    --------------------------------- ------ 29/35 [argon2-cffi]
#    ---------------------------------- ----- 30/35 [nbformat]
#    ---------------------------------- ----- 30/35 [nbformat]
#    ---------------------------------- ----- 30/35 [nbformat]
#    ---------------------------------- ----- 30/35 [nbformat]
#    ----------------------------------- ---- 31/35 [nbclient]
#    ------------------------------------ --- 32/35 [jupyter-events]
#    ------------------------------------- -- 33/35 [nbconvert]
#    ------------------------------------- -- 33/35 [nbconvert]
#    ------------------------------------- -- 33/35 [nbconvert]
#    ------------------------------------- -- 33/35 [nbconvert]
#    ------------------------------------- -- 33/35 [nbconvert]
#    ------------------------------------- -- 33/35 [nbconvert]
#    ------------------------------------- -- 33/35 [nbconvert]
#    ------------------------------------- -- 33/35 [nbconvert]
#    -------------------------------------- - 34/35 [jupyter-server]
#    -------------------------------------- - 34/35 [jupyter-server]
#    -------------------------------------- - 34/35 [jupyter-server]
#    -------------------------------------- - 34/35 [jupyter-server]
#    -------------------------------------- - 34/35 [jupyter-server]
#    -------------------------------------- - 34/35 [jupyter-server]
#    -------------------------------------- - 34/35 [jupyter-server]
#    ---------------------------------------- 35/35 [jupyter-server]
#
# Successfully installed argon2-cffi-25.1.0 argon2-cffi-bindings-25.1.0 arrow-1.4.0 beautifulsoup4-4.14.2 bleach-6.3.0 defusedxml-0.7.1 fastjsonschema-2.21.2 fqdn-1.5.1 isoduration-20.11.0 jinja2-3.1.6 jsonpointer-3.0.0 jupyter-events-0.12.0 jupyter-server-2.17.0 jupyter-server-terminals-0.5.3 jupyterlab-pygments-0.3.0 lark-1.3.1 mistune-3.1.4 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 pandocfilters-1.5.1 prometheus-client-0.23.1 python-json-logger-4.0.0 pywinpty-3.0.2 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rfc3987-syntax-1.1.0 send2trash-1.8.3 soupsieve-2.8 terminado-0.18.1 tinycss2-1.4.0 uri-template-1.3.0 webcolors-25.10.0 webencodings-0.5.1 websocket-client-1.9.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ✅ Helper functions defined.

# %%
# !adk create research-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in c:\Users\ashis\Agentic AI Day 4\Agentic-AI-Day-4\research-agent:
# - .env
# - __init__.py
# - agent.py

# %%
# %%writefile research-agent/agent.py

from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.tools.agent_tool import AgentTool
from google.adk.tools.google_search_tool import google_search

from google.genai import types
from typing import List

retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# ---- Intentionally pass incorrect datatype - `str` instead of `List[str]` ----
def count_papers(papers: str):
    """
    This function counts the number of papers in a list of strings.
    Args:
      papers: A list of strings, where each string is a research paper.
    Returns:
      The number of papers in the list.
    """
    return len(papers)


# Google Search agent
google_search_agent = LlmAgent(
    name="google_search_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    description="Searches for information using Google search",
    instruction="""Use the google_search tool to find information on the given topic. Return the raw search results.
    If the user asks for a list of papers, then give them the list of research papers you found and not the summary.""",
    tools=[google_search]
)


# Root agent
root_agent = LlmAgent(
    name="research_paper_finder_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""Your task is to find research papers and count them. 

    You MUST ALWAYS follow these steps:
    1) Find research papers on the user provided topic using the 'google_search_agent'. 
    2) Then, pass the papers to 'count_papers' tool to count the number of papers returned.
    3) Return both the list of research papers and the total number of papers.
    """,
    tools=[AgentTool(agent=google_search_agent), count_papers]
)
# Out:
# Overwriting research-agent/agent.py

# %%
url_prefix = get_adk_proxy_url()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 url_prefix = get_adk_proxy_url()
#
# Cell In[9], line 15, in get_adk_proxy_url()
#      13 servers = list(list_running_servers())
#      14 if not servers:
# ---> 15     raise Exception("No running Jupyter servers found.")
#      17 baseURL = servers[0]["base_url"]
#      19 try:
#
# Exception: No running Jupyter servers found.

# %%
# !adk web --log_level DEBUG --url_prefix {url_prefix}
# Out:
# ^C
