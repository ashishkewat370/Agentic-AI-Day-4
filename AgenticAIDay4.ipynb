# %%
# Install the Gemini client if it's not already available
pip install google-adk

import os
import google.generativeai as genai

try:
    # Set your API key here OR ensure it's set in the environment (recommended).
    # Replace 'ADD_YOUR_API_KEY_HERE' with your real API key or remove the assignment to rely on an already-set env var.
    os.environ["GOOGLE_API_KEY"] = os.environ.get("GOOGLE_API_KEY", "ADD_YOUR_API_KEY_HERE")
    genai.configure(api_key=os.environ["GOOGLE_API_KEY"])
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your environment. Details: {e}"
    )
# Out:
# ERROR: Could not find a version that satisfies the requirement google-generative-ai (from versions: none)
# ERROR: No matching distribution found for google-generative-ai
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\ashis\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# c:\Users\ashis\AppData\Local\Programs\Python\Python39\lib\site-packages\google\api_core\_python_version_support.py:252: FutureWarning: You are using a Python version (3.9.13) past its end of life. Google will update google.api_core with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# Note: you may need to restart the kernel to use updated packages.
# ...
